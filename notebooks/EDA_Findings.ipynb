# %%
## Finding 1

Daily NAV across the 40 mutual fund schemes showed an overall upward trend from 2022 to 2026, with noticeable growth during the 2023 bull market.

**Supporting Chart:** NAV_Trend_Analysis.ipynb

# %%
## Finding 2

Assets Under Management (AUM) increased consistently across all major fund houses between 2022 and 2025, with SBI maintaining the highest AUM.

**Supporting Chart:** AUM_Growth_Analysis.ipynb

# %%
## Finding 3

Monthly SIP inflows steadily increased from 2022 to 2025 and reached an all-time high of ₹31,002 crore in December 2025.

**Supporting Chart:** SIP_Inflow_Trend_Analysis.ipynb

# %%
## Finding 4

Category-wise inflows varied across months, with equity-oriented categories receiving higher net inflows than most other categories.

**Supporting Chart:** Category_Inflow_Heatmap.ipynb

# %%
## Finding 5

The 26–35 and 36–45 age groups accounted for a significant share of investors, indicating strong participation from working professionals.

**Supporting Chart:** Investor_Demographics_Analysis.ipynb

# %%
## Finding 6

SIP investments were distributed across multiple states, with some states contributing substantially higher total SIP amounts than others.

**Supporting Chart:** Geographic_Distribution_Analysis.ipynb

# %%
## Finding 7

Total mutual fund folios increased from 13.26 crore in January 2022 to 26.12 crore in December 2025, reflecting sustained industry growth.

**Supporting Chart:** Folio_Count_Growth_Analysis.ipynb

# %%
## Finding 8

Several selected mutual funds exhibited positive correlations in daily NAV returns, suggesting similar market movement patterns.

**Supporting Chart:** NAV_Return_Correlation_Matrix.ipynb

# %%
## Finding 9

Portfolio allocations were diversified across sectors, with Banking, Utilities, Pharma, Diversified, and Paints contributing significant portfolio weights.

**Supporting Chart:** Sector_Allocation_Analysis.ipynb

# %%
## Finding 10

The combined EDA indicates strong growth in the mutual fund industry, supported by increasing AUM, rising SIP inflows, expanding folio counts, and diversified portfolios.

**Supporting Charts:** 03–11 Analysis Notebooks
