# %%
# Fund scorecard load
import pandas as pd

scorecard = pd.read_csv("../data/processed/fund_scorecard.csv")

scorecard.columns
# Out:
# Index(['amfi_code', 'CAGR_3Y', 'Sharpe_Ratio', 'Alpha', 'Maximum_Drawdown',
#        'expense_ratio_pct', 'Return_Rank', 'Sharpe_Rank', 'Alpha_Rank',
#        'Expense_Rank', 'Drawdown_Rank', 'Return_Score', 'Sharpe_Score',
#        'Alpha_Score', 'Expense_Score', 'Drawdown_Score', 'Fund_Score',
#        'Overall_Rank'],
#       dtype='object')

# %%
def assign_risk_grade(dd):
    dd = abs(dd)

    if dd <= 0.15:
        return "Low"
    elif dd <= 0.30:
        return "Moderate"
    else:
        return "High"

scorecard["risk_grade"] = scorecard["Maximum_Drawdown"].apply(
    assign_risk_grade
)

# %%
# Top 3 recommender
def recommend_funds(risk_appetite):

    recommendations = scorecard[
        scorecard["risk_grade"].str.lower() == risk_appetite.lower()
    ].copy()

    recommendations = recommendations.sort_values(
        "Sharpe_Ratio",
        ascending=False
    )

    return recommendations[
        ["amfi_code", "risk_grade", "Sharpe_Ratio", "Fund_Score"]
    ].head(3)

# %%
# User input
risk_appetite = input(
    "Enter risk appetite (Low / Moderate / High): "
)

recommended_funds = recommend_funds(risk_appetite)

print("\nTop 3 Fund Recommendations:")
print(recommended_funds.to_string(index=False))
# Out:
# Enter risk appetite (Low / Moderate / High):  High
# Top 3 Fund Recommendations:
#  amfi_code risk_grade  Sharpe_Ratio  Fund_Score
#     149324       High      0.971126   65.833333
#     101207       High      0.197367   20.064103
#     119599       High     -0.032155   23.012821
